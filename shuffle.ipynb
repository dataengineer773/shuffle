# %%
from random import shuffle

# %%
l = list(range(62))

# %%
shuffle(l)

# %%
l
# Out:
# [46,
#  59,
#  38,
#  54,
#  20,
#  48,
#  35,
#  29,
#  13,
#  55,
#  31,
#  24,
#  41,
#  40,
#  3,
#  1,
#  33,
#  6,
#  14,
#  2,
#  8,
#  56,
#  17,
#  44,
#  36,
#  43,
#  16,
#  34,
#  21,
#  0,
#  4,
#  47,
#  25,
#  58,
#  12,
#  11,
#  15,
#  52,
#  61,
#  57,
#  9,
#  26,
#  22,
#  32,
#  45,
#  19,
#  53,
#  49,
#  5,
#  28,
#  37,
#  27,
#  30,
#  51,
#  10,
#  39,
#  7,
#  50,
#  18,
#  42,
#  60,
#  23]
